# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("Breast Cancer Data Set.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df = df.drop(columns = "Unnamed: 32", axis=1)

# %%
x = df.iloc[:,3:-1].values
y = df.iloc[:,-1].values

# %%
x
# Out:
# array([[1.038e+01, 1.228e+02, 1.001e+03, ..., 7.119e-01, 2.654e-01,
#         4.601e-01],
#        [1.777e+01, 1.329e+02, 1.326e+03, ..., 2.416e-01, 1.860e-01,
#         2.750e-01],
#        [2.125e+01, 1.300e+02, 1.203e+03, ..., 4.504e-01, 2.430e-01,
#         3.613e-01],
#        ...,
#        [2.808e+01, 1.083e+02, 8.581e+02, ..., 3.403e-01, 1.418e-01,
#         2.218e-01],
#        [2.933e+01, 1.401e+02, 1.265e+03, ..., 9.387e-01, 2.650e-01,
#         4.087e-01],
#        [2.454e+01, 4.792e+01, 1.810e+02, ..., 0.000e+00, 0.000e+00,
#         2.871e-01]])

# %%
y
# Out:
# array([0.1189 , 0.08902, 0.08758, 0.173  , 0.07678, 0.1244 , 0.08368,
#        0.1151 , 0.1072 , 0.2075 , 0.08452, 0.1048 , 0.1023 , 0.06287,
#        0.1431 , 0.1341 , 0.08216, 0.1142 , 0.07615, 0.07259, 0.08183,
#        0.07773, 0.09946, 0.07526, 0.09564, 0.1059 , 0.1275 , 0.07421,
#        0.09876, 0.07919, 0.09782, 0.1402 , 0.08482, 0.1123 , 0.1233 ,
#        0.08633, 0.1014 , 0.06169, 0.05504, 0.1071 , 0.07146, 0.09606,
#        0.1038 , 0.1027 , 0.09618, 0.09185, 0.07409, 0.1179 , 0.08301,
#        0.06917, 0.06563, 0.08025, 0.07408, 0.07987, 0.07873, 0.07036,
#        0.08294, 0.1094 , 0.06289, 0.09026, 0.0802 , 0.07712, 0.1132 ,
#        0.0849 , 0.1031 , 0.08911, 0.09211, 0.06641, 0.1175 , 0.0641 ,
#        0.06589, 0.1084 , 0.1339 , 0.103  , 0.07609, 0.06387, 0.07191,
#        0.1108 , 0.09964, 0.07918, 0.08851, 0.1016 , 0.1051 , 0.09203,
#        0.07924, 0.08579, 0.06846, 0.09288, 0.09261, 0.08473, 0.07246,
#        0.06828, 0.06206, 0.06603, 0.08234, 0.08368, 0.07376, 0.08988,
#        0.08756, 0.09353, 0.07397, 0.09382, 0.06878, 0.0849 , 0.07552,
#        0.1405 , 0.09097, 0.07185, 0.09789, 0.08832, 0.08468, 0.08486,
#        0.1082 , 0.09026, 0.1017 , 0.08541, 0.07722, 0.1065 , 0.1252 ,
#        0.06111, 0.08523, 0.08456, 0.08009, 0.08006, 0.07628, 0.07182,
#        0.079  , 0.06541, 0.07779, 0.08465, 0.09241, 0.08019, 0.07619,
#        0.07071, 0.0761 , 0.08067, 0.07343, 0.06765, 0.07147, 0.06784,
#        0.08151, 0.08158, 0.08096, 0.08118, 0.06769, 0.1036 , 0.103  ,
#        0.09218, 0.07683, 0.07014, 0.06435, 0.1486 , 0.1259 , 0.06772,
#        0.08633, 0.08132, 0.07738, 0.05972, 0.07898, 0.07685, 0.07987,
#        0.06251, 0.09223, 0.09082, 0.09187, 0.06085, 0.07699, 0.07228,
#        0.093  , 0.06428, 0.06771, 0.07371, 0.101  , 0.07313, 0.06164,
#        0.07848, 0.1162 , 0.09519, 0.05843, 0.07319, 0.08082, 0.1284 ,
#        0.08631, 0.07427, 0.09772, 0.07697, 0.06938, 0.07097, 0.06576,
#        0.06306, 0.1446 , 0.06871, 0.06559, 0.1205 , 0.08701, 0.06949,
#        0.09333, 0.06558, 0.09221, 0.1013 , 0.08174, 0.07867, 0.08762,
#        0.1086 , 0.0875 , 0.0974 , 0.0738 , 0.06469, 0.1076 , 0.07474,
#        0.05865, 0.07993, 0.05525, 0.06818, 0.1026 , 0.1059 , 0.08365,
#        0.07809, 0.08255, 0.07568, 0.08718, 0.08177, 0.08797, 0.1064 ,
#        0.07623, 0.06072, 0.08269, 0.08362, 0.09585, 0.1243 , 0.09061,
#        0.07087, 0.07307, 0.08328, 0.08178, 0.07617, 0.08677, 0.07127,
#        0.07796, 0.08496, 0.0651 , 0.06783, 0.1297 , 0.06321, 0.07614,
#        0.07748, 0.07198, 0.1178 , 0.08147, 0.07809, 0.07849, 0.06487,
#        0.1297 , 0.08113, 0.0895 , 0.07957, 0.1005 , 0.1191 , 0.1019 ,
#        0.1204 , 0.07999, 0.06515, 0.07484, 0.06829, 0.0757 , 0.08218,
#        0.07587, 0.07024, 0.07062, 0.08701, 0.0612 , 0.08022, 0.08858,
#        0.08175, 0.07948, 0.06033, 0.06386, 0.05737, 0.06263, 0.06912,
#        0.0972 , 0.06688, 0.07787, 0.1063 , 0.07127, 0.06431, 0.09981,
#        0.06915, 0.07009, 0.06994, 0.08799, 0.08472, 0.09584, 0.07007,
#        0.06922, 0.06794, 0.06643, 0.06915, 0.07676, 0.06777, 0.09929,
#        0.07764, 0.09469, 0.07842, 0.07638, 0.06745, 0.08385, 0.07804,
#        0.06192, 0.0658 , 0.06958, 0.05695, 0.08253, 0.07434, 0.08116,
#        0.06174, 0.06037, 0.08198, 0.1055 , 0.05932, 0.09702, 0.05933,
#        0.08553, 0.1024 , 0.07961, 0.06888, 0.07083, 0.07037, 0.082  ,
#        0.07953, 0.09124, 0.09166, 0.06522, 0.07418, 0.07207, 0.07599,
#        0.1009 , 0.0987 , 0.07664, 0.07738, 0.08764, 0.09825, 0.0908 ,
#        0.07918, 0.07806, 0.08488, 0.08083, 0.08187, 0.08763, 0.0759 ,
#        0.06825, 0.105  , 0.08815, 0.09438, 0.07018, 0.07188, 0.08317,
#        0.07113, 0.07431, 0.08136, 0.05521, 0.06658, 0.07238, 0.06469,
#        0.07582, 0.06735, 0.07632, 0.0747 , 0.06494, 0.08574, 0.09614,
#        0.06766, 0.08666, 0.07055, 0.07701, 0.0896 , 0.12   , 0.07061,
#        0.09638, 0.1403 , 0.09215, 0.07287, 0.09349, 0.1118 , 0.0732 ,
#        0.06836, 0.08824, 0.06623, 0.1043 , 0.07602, 0.07722, 0.08865,
#        0.1019 , 0.1007 , 0.07081, 0.06609, 0.07686, 0.07053, 0.09158,
#        0.08121, 0.1198 , 0.07262, 0.07247, 0.07834, 0.05974, 0.07732,
#        0.07012, 0.08151, 0.08503, 0.06896, 0.07745, 0.07881, 0.09206,
#        0.09251, 0.06165, 0.07351, 0.08304, 0.1048 , 0.09464, 0.07123,
#        0.08284, 0.09208, 0.07427, 0.08839, 0.08009, 0.08061, 0.09646,
#        0.07662, 0.07083, 0.06025, 0.1155 , 0.09359, 0.08075, 0.08314,
#        0.06827, 0.1055 , 0.07735, 0.07234, 0.06911, 0.0671 , 0.09532,
#        0.07944, 0.0681 , 0.06736, 0.08225, 0.08251, 0.09075, 0.07285,
#        0.07463, 0.07425, 0.09952, 0.06091, 0.08194, 0.0781 , 0.0733 ,
#        0.07675, 0.0722 , 0.06788, 0.06291, 0.07211, 0.0906 , 0.07427,
#        0.06464, 0.07863, 0.06925, 0.1249 , 0.08174, 0.07875, 0.1224 ,
#        0.0927 , 0.08524, 0.06639, 0.08273, 0.06743, 0.108  , 0.07802,
#        0.07858, 0.07698, 0.0918 , 0.09136, 0.07729, 0.07603, 0.09326,
#        0.0696 , 0.08181, 0.1034 , 0.06596, 0.09009, 0.08024, 0.07623,
#        0.08203, 0.05871, 0.07625, 0.07028, 0.07429, 0.06599, 0.1033 ,
#        0.07661, 0.09445, 0.08999, 0.08549, 0.1183 , 0.07538, 0.07277,
#        0.1252 , 0.1364 , 0.08839, 0.1168 , 0.0723 , 0.1067 , 0.09879,
#        0.06142, 0.1109 , 0.07048, 0.06954, 0.06783, 0.07863, 0.09136,
#        0.08893, 0.08557, 0.08982, 0.09671, 0.07613, 0.09031, 0.09209,
#        0.1049 , 0.08665, 0.07592, 0.07253, 0.08052, 0.07757, 0.0895 ,
#        0.07782, 0.06386, 0.08278, 0.07569, 0.08351, 0.0997 , 0.09938,
#        0.1066 , 0.08134, 0.1023 , 0.06956, 0.06443, 0.08492, 0.06953,
#        0.07399, 0.09479, 0.0792 , 0.07626, 0.06592, 0.08032, 0.06484,
#        0.07393, 0.07242, 0.08283, 0.06742, 0.06969, 0.08004, 0.08732,
#        0.08321, 0.05905, 0.1409 , 0.09873, 0.07115, 0.06637, 0.0782 ,
#        0.124  , 0.07039])

# %%
from sklearn .preprocessing import LabelEncoder

le = LabelEncoder()
le2 = LabelEncoder()

x[:,1] = le.fit_transform(x[:,1])
x[:,2] = le.fit_transform(x[:,2])

# %%
x
# Out:
# array([[1.038e+01, 4.550e+02, 4.520e+02, ..., 7.119e-01, 2.654e-01,
#         4.601e-01],
#        [1.777e+01, 4.860e+02, 5.130e+02, ..., 2.416e-01, 1.860e-01,
#         2.750e-01],
#        [2.125e+01, 4.780e+02, 4.870e+02, ..., 4.504e-01, 2.430e-01,
#         3.613e-01],
#        ...,
#        [2.808e+01, 4.100e+02, 4.210e+02, ..., 3.403e-01, 1.418e-01,
#         2.218e-01],
#        [2.933e+01, 5.000e+02, 5.010e+02, ..., 9.387e-01, 2.650e-01,
#         4.087e-01],
#        [2.454e+01, 1.000e+00, 3.000e+00, ..., 0.000e+00, 0.000e+00,
#         2.871e-01]])

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
from sklearn .preprocessing import StandardScaler

sc = StandardScaler()

xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %%
# 1.Initilize the ANN Model

model = Sequential()

# 2.Pass hidden layer

model.add(Dense(units = 6, activation = "relu"))

# 3.Pass Activation Funcation

model.add(Dense(units = 1, activation = "sigmoid"))

# 4.To Establish the connection between layers

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

# 5.Train the model

model.fit(xtrain, ytrain, batch_size = 30, epochs = 100)

# 6.Take Prediction

ypred = model.predict(xtest)

# 7.Set Threshhold Value

ypred = ypred>0.5

# 8.Get classification report

print(classification_report(ytest,ypred))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 2s 7ms/step - loss: 0.8752 - accuracy: 0.0000e+00
# Epoch 2/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7912 - accuracy: 0.0000e+00
# Epoch 3/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7158 - accuracy: 0.0000e+00
# Epoch 4/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6535 - accuracy: 0.0000e+00
# Epoch 5/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5982 - accuracy: 0.0000e+00
# Epoch 6/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5502 - accuracy: 0.0000e+00
# Epoch 7/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5106 - accuracy: 0.0000e+00
# Epoch 8/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4783 - accuracy: 0.0000e+00
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4530 - accuracy: 0.0000e+00
# Epoch 10/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4320 - accuracy: 0.0000e+00
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4152 - accuracy: 0.0000e+00
# Epoch 12/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4020 - accuracy: 0.0000e+00
# Epoch 13/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3910 - accuracy: 0.0000e+00
# Epoch 14/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3823 - accuracy: 0.0000e+00
# Epoch 15/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3750 - accuracy: 0.0000e+00
# Epoch 16/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3688 - accuracy: 0.0000e+00
# Epoch 17/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3635 - accuracy: 0.0000e+00
# Epoch 18/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3592 - accuracy: 0.0000e+00
# Epoch 19/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3554 - accuracy: 0.0000e+00
# Epoch 20/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3522 - accuracy: 0.0000e+00
# Epoch 21/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3493 - accuracy: 0.0000e+00
# Epoch 22/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3468 - accuracy: 0.0000e+00
# Epoch 23/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3444 - accuracy: 0.0000e+00
# Epoch 24/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3423 - accuracy: 0.0000e+00
# Epoch 25/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3402 - accuracy: 0.0000e+00
# Epoch 26/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3384 - accuracy: 0.0000e+00
# Epoch 27/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3366 - accuracy: 0.0000e+00
# Epoch 28/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3351 - accuracy: 0.0000e+00
# Epoch 29/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3336 - accuracy: 0.0000e+00
# Epoch 30/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3320 - accuracy: 0.0000e+00
# Epoch 31/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3304 - accuracy: 0.0000e+00
# Epoch 32/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3291 - accuracy: 0.0000e+00
# Epoch 33/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3277 - accuracy: 0.0000e+00
# Epoch 34/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3264 - accuracy: 0.0000e+00
# Epoch 35/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3251 - accuracy: 0.0000e+00
# Epoch 36/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3239 - accuracy: 0.0000e+00
# Epoch 37/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3228 - accuracy: 0.0000e+00
# Epoch 38/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3217 - accuracy: 0.0000e+00
# Epoch 39/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3207 - accuracy: 0.0000e+00
# Epoch 40/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3196 - accuracy: 0.0000e+00
# Epoch 41/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3187 - accuracy: 0.0000e+00
# Epoch 42/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3176 - accuracy: 0.0000e+00
# Epoch 43/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3168 - accuracy: 0.0000e+00
# Epoch 44/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3158 - accuracy: 0.0000e+00
# Epoch 45/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3149 - accuracy: 0.0000e+00
# Epoch 46/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3140 - accuracy: 0.0000e+00
# Epoch 47/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3131 - accuracy: 0.0000e+00
# Epoch 48/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3123 - accuracy: 0.0000e+00
# Epoch 49/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3115 - accuracy: 0.0000e+00
# Epoch 50/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3107 - accuracy: 0.0000e+00
# Epoch 51/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3099 - accuracy: 0.0000e+00
# Epoch 52/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3091 - accuracy: 0.0000e+00
# Epoch 53/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3083 - accuracy: 0.0000e+00
# Epoch 54/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3076 - accuracy: 0.0000e+00
# Epoch 55/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 0.0000e+00
# Epoch 56/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3063 - accuracy: 0.0000e+00
# Epoch 57/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3056 - accuracy: 0.0000e+00
# Epoch 58/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3050 - accuracy: 0.0000e+00
# Epoch 59/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3044 - accuracy: 0.0000e+00
# Epoch 60/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3038 - accuracy: 0.0000e+00
# Epoch 61/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3033 - accuracy: 0.0000e+00
# Epoch 62/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3028 - accuracy: 0.0000e+00
# Epoch 63/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3023 - accuracy: 0.0000e+00
# Epoch 64/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3018 - accuracy: 0.0000e+00
# Epoch 65/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3014 - accuracy: 0.0000e+00
# Epoch 66/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3011 - accuracy: 0.0000e+00
# Epoch 67/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3006 - accuracy: 0.0000e+00
# Epoch 68/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3002 - accuracy: 0.0000e+00
# Epoch 69/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2999 - accuracy: 0.0000e+00
# Epoch 70/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2995 - accuracy: 0.0000e+00
# Epoch 71/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2992 - accuracy: 0.0000e+00
# Epoch 72/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2989 - accuracy: 0.0000e+00
# Epoch 73/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2986 - accuracy: 0.0000e+00
# Epoch 74/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2982 - accuracy: 0.0000e+00
# Epoch 75/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2980 - accuracy: 0.0000e+00
# Epoch 76/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2977 - accuracy: 0.0000e+00
# Epoch 77/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2974 - accuracy: 0.0000e+00
# Epoch 78/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2972 - accuracy: 0.0000e+00
# Epoch 79/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2969 - accuracy: 0.0000e+00
# Epoch 80/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2967 - accuracy: 0.0000e+00
# Epoch 81/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2965 - accuracy: 0.0000e+00
# Epoch 82/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2963 - accuracy: 0.0000e+00
# Epoch 83/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2960 - accuracy: 0.0000e+00
# Epoch 84/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2958 - accuracy: 0.0000e+00
# Epoch 85/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2956 - accuracy: 0.0000e+00
# Epoch 86/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2954 - accuracy: 0.0000e+00
# Epoch 87/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2953 - accuracy: 0.0000e+00
# Epoch 88/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2951 - accuracy: 0.0000e+00
# Epoch 89/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2949 - accuracy: 0.0000e+00
# Epoch 90/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2947 - accuracy: 0.0000e+00
# Epoch 91/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2946 - accuracy: 0.0000e+00
# Epoch 92/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2944 - accuracy: 0.0000e+00
# Epoch 93/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2943 - accuracy: 0.0000e+00
# Epoch 94/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2941 - accuracy: 0.0000e+00
# Epoch 95/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2940 - accuracy: 0.0000e+00
# Epoch 96/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2939 - accuracy: 0.0000e+00
# Epoch 97/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2937 - accuracy: 0.0000e+00
# Epoch 98/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2936 - accuracy: 0.0000e+00
# Epoch 99/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2935 - accuracy: 0.0000e+00
# Epoch 100/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2934 - accuracy: 0.0000e+00
# 6/6 [==============================] - 0s 6ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 31>()
#      27 ypred = ypred>0.5
#      29 # 8.Get classification report
# ---> 31 print(classification_report(ytest,ypred))
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:2110, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1998 def classification_report(
#    1999     y_true,
#    2000     y_pred,
#    (...)
#    2007     zero_division="warn",
#    2008 ):
#    2009     """Build a text report showing the main classification metrics.
#    2010
#    2011     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2107     <BLANKLINE>
#    2108     """
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2112     if labels is None:
#    2113         labels = unique_labels(y_true, y_pred)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:93, in _check_targets(y_true, y_pred)
#      90     y_type = {"multiclass"}
#      92 if len(y_type) > 1:
# ---> 93     raise ValueError(
#      94         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95             type_true, type_pred
#      96         )
#      97     )
#      99 # We can't have more than one value on y_type => The set is no more needed
#     100 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of continuous and binary targets

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()

logreg.fit(xtrain, ytrain)

ypred = logreg.predict(xtest)

print(classification_report(ytest, ypred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 5>()
#       1 from sklearn.linear_model import LogisticRegression
#       3 logreg = LogisticRegression()
# ----> 5 logreg.fit(xtrain, ytrain)
#       7 ypred = logreg.predict(xtest)
#       9 print(classification_report(ytest, ypred))
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1516, in LogisticRegression.fit(self, X, y, sample_weight)
#    1506     _dtype = [np.float64, np.float32]
#    1508 X, y = self._validate_data(
#    1509     X,
#    1510     y,
#    (...)
#    1514     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515 )
# -> 1516 check_classification_targets(y)
#    1517 self.classes_ = np.unique(y)
#    1519 multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py:197, in check_classification_targets(y)
#     189 y_type = type_of_target(y)
#     190 if y_type not in [
#     191     "binary",
#     192     "multiclass",
#    (...)
#     195     "multilabel-sequences",
#     196 ]:
# --> 197     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'
